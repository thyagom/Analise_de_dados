# %%
import pandas as pd

tabela = pd.read_csv('clientes.csv',encoding='latin1',sep=';')
tabela = tabela.drop('Unnamed: 8',axis=1)
tabela = tabela.drop('ClienteID',axis=1)
filtro = tabela['Idade'] > 18
tabela = tabela[filtro]
tabela['Salário Anual (R$)'] = pd.to_numeric(tabela['Salário Anual (R$)'],errors='coerce')
tabela = tabela.dropna()
print(tabela.info())
      
display(tabela)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1615 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Origem                1615 non-null   object
#  1   Idade                 1615 non-null   int64
#  2   Salário Anual (R$)    1615 non-null   float64
#  3   Nota (1-100)          1615 non-null   int64
#  4   Profissão             1615 non-null   object
#  5   Experiência Trabalho  1615 non-null   int64
#  6   Tamanho Família       1615 non-null   int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 100.9+ KB
# None
#         Origem  Idade  Salário Anual (R$)  Nota (1-100)       Profissão
# 0       Normal     19             15000.0            39           Saúde  \
# 1       Normal     21             35000.0            81      Engenheiro
# 2     Promoção     20             86000.0             2      Engenheiro
# 3     Promoção     23             59000.0            73        Advogado
# 4     Promoção     31             38000.0            48  Entretenimento
# ...        ...    ...                 ...           ...             ...
# 1995  Promoção     71            184387.0            48         Artista
# 1996  Promoção     91             73158.0            28          Doutor
# 1997    Normal     87             90961.0            14           Saúde
# 1998    Normal     77            182109.0             4       Executivo
# 1999    Normal     90            110610.0            64  Entretenimento
#
#       Experiência Trabalho  Tamanho Família
# 0                        1                4
# 1                        3                3
# 2                        1                1
# 3                        0                2
# 4                        2                6
# ...                    ...              ...
# 1995                     8                7
# 1996                     7                7
# 1997                     9                2
# 1998                     7                2
# 1999                     5                2
#
# [1615 rows x 7 columns]

# %%
import plotly.express as px

for coluna in tabela.columns:
    grafico = px.histogram(tabela, x=coluna, y="Nota (1-100)",histfunc='avg', text_auto=True, nbins=10)
    
    grafico.show()
